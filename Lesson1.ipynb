# %% [markdown]
# ## Einführung Phyton

# %% [markdown]
# #### Warum Phyton?  --> Beliebt, Modern, einfach

# %%
import cv2

import matplotlib.pyplot as plt
import matplotlib

img = cv2.imread("Sprachen.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
def show_image(img, pixel_size_in_inch=0.02):
    fig_height_inch = int(img.shape[0] * pixel_size_in_inch)
    fig_width_inch  = int(img.shape[1] * pixel_size_in_inch)
    plt.figure(figsize=(fig_height_inch,fig_width_inch))
    plt.imshow(img)
    
show_image(img)
print("Source: https://spectrum.ieee.org/static/interactive-the-top-programming-languages-2018")
# Out:
# Source: https://spectrum.ieee.org/static/interactive-the-top-programming-languages-2018

# %% [markdown]
# #### How to geht started
# 1. https://colab.research.google.com/
#     + Keine lokale Installation nötig
#     + Performance
#     + "Alle" Bibliotheken verfügbar
#     + Daten sind immer "dabei"
#     - Einbinden von lokalen Dateien
# 2. https://repl.it/languages/phyton3
#     Console statt "Jupiter Notebook
#     + Keine lokale Installation nötig
#     + einfach
#     - Bibliotheke verfügbar?
#     - Einbinden von lokalen Dateien
# 3. https://www.anacona.com/
#     Lokale Installation
#     - Bibliotheken müssen "selbst installiert" werden

# %% [markdown]
# #### Ein- und Ausgabe

# %%
a=input("Zahl eingeben")
print(a)
# Out:
# Zahl eingeben 10
# 10

# %% [markdown]
# #### Variabeln
# https://www.python-kurs.eu/python3_variablen.php

# %%
dtype(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-417b5e91ea4a> in <module>
# ----> 1 dtype(a)
#
# NameError: name 'dtype' is not defined
